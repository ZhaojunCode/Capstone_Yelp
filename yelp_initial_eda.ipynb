# %%
import os
## Mount S3 bucket to the Databricks File System
s3Path = "s3a://{0}:{1}@{2}".format("AKIAJCGOAE4K3YAR7XAQ", 
                                    "SczIv13FUdQgHos7Od5lIvn2YpLekbNNCxOtt1Ti", 
                                    "nycdsa-yelp")
mntPath = "/mnt/data/"
try:
  dbutils.fs.mount(s3Path, mntPath)
except:
  print 'failed to mount'

# %%
#Display all of the available files in our bucket
display(dbutils.fs.ls("{}/{}".format(mntPath,'yelp')))

# %%
#import the Business dataset
businessPath = os.path.join(mntPath, 'yelp', 'yelp_academic_dataset_business.json')

businessDF = sqlContext.read.json(businessPath)
businessDF.show()

# %%
businessDF.printSchema()
#Looks like the array collumns will take a fair bit of processing
#Probably need to reimport with set schema?

# %%
businessDF.groupBy('city').agg({"*":"count", "review_count":"avg"})\
.orderBy('count(1)', ascending=False)\
.withColumnRenamed('count(1)', '# Business/City')\
.withColumnRenamed('avg(review_count)', 'Avg # Reviews/Business')\
.show(25)

# %%
x = businessDF.rdd.map(lambda x: x.city.lower()).take(1)

# %%
checkinPath = os.path.join(mntPath, 'yelp', 'yelp_academic_dataset_checkin.json')

checkinDF = sqlContext.read.json(checkinPath)
checkinDF.show()

# %%
checkinDF.printSchema()
#Looks like the time array will take a fair bit of processing
#Probably need to reimport with set schema?

# %%
reviewPath = os.path.join(mntPath, 'yelp', 'yelp_academic_dataset_review.json')

reviewDF = sqlContext.read.json(reviewPath)
reviewDF.show()

# %%
reviewDF.printSchema()
